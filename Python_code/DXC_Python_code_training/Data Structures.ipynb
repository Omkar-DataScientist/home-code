# %% [markdown]
# # Built-in Data Structure in Python

# %% [markdown]
# ## List

# %% [markdown]
# Lists are written as a list of comma-separated values (items) between `square brackets`. It might contain items of different types, but usually the items all have the same type.

# %%
a = [1, 2, 3]

# %%
a
# Out:
# [1, 2, 3]

# %% [markdown]
# ### Defining an empty list

# %%
a = list ()
a
# Out:
# []

# %%
a = []
a
# Out:
# []

# %% [markdown]
# ### Creating using iterable objects

# %% [markdown]
# `list`, built-in function can be used to create a list data type using any object that is iterable such as a string

# %%
list ('apple')
# Out:
# ['a', 'p', 'p', 'l', 'e']

# %% [markdown]
# Question: What's the output?

# %%
['apple']
# Out:
# ['apple']

# %% [markdown]
# ### Accessing a list (similar to accessing strings)
# 0 indexed

# %%
a = [1, 2, 3, 4, 5, 6]

# %%
a [4]
# Out:
# 5

# %% [markdown]
# Using negative indexing

# %%
a [-1]
# Out:
# 6

# %% [markdown]
# Question: Whats' the output?

# %%
a [-4:-1]
# Out:
# [3, 4, 5]

# %% [markdown]
# ### Mutability of lists

# %%
a
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
a [0] = 10

# %%
a
# Out:
# [10, 2, 3, 4, 5, 6]

# %% [markdown]
# Unlike strings, lists are mutable i.e. the items that make up the list can be modified

# %% [markdown]
# ### Using assignment with lists

# %%
b = a

# %%
a, b
# Out:
# ([10, 2, 3, 4, 5, 6], [10, 2, 3, 4, 5, 6])

# %%
b [2] = 100

# %% [markdown]
# Question: What are the values of `a` and `b`?

# %%
b
# Out:
# [10, 2, 100, 4, 5, 6]

# %%
a
# Out:
# [10, 2, 100, 4, 5, 6]

# %% [markdown]
# Again unlike strings, lists passes the object references while assigning

# %% [markdown]
# Where would knowing this be useful?

# %%
string = string1 = 'apple'

# %%
string, string1
# Out:
# ('apple', 'apple')

# %%
string = 'ball'

# %%
string, string1
# Out:
# ('ball', 'apple')

# %% [markdown]
# But don't do this with lists.. not good idea

# %%
list1 = list2 = [1, 2, 3]

# %%
list1 [0] = 100

# %%
list1, list2
# Out:
# ([100, 2, 3], [100, 2, 3])

# %% [markdown]
# Question: What does the following do?

# %%
x = a [:]

# %%
x
# Out:
# [10, 2, 100, 4, 5, 6]

# %%
x [0] = 500

# %%
x, a
# Out:
# ([500, 2, 100, 4, 5, 6], [10, 2, 100, 4, 5, 6])

# %%
hex (id (a))
# Out:
# '0x111d67580'

# %%
hex (id (x))
# Out:
# '0x111d41080'

# %% [markdown]
# A slice returns a new list and not a reference pointing to the old one

# %% [markdown]
# ### Appending to lists

# %%
a
# Out:
# [10, 2, 100, 4, 5, 6]

# %%
x
# Out:
# [500, 2, 100, 4, 5, 6]

# %% [markdown]
# What would this do?

# %%
a + x
# Out:
# [10, 2, 100, 4, 5, 6, 500, 2, 100, 4, 5, 6]

# %% [markdown]
# What if u want to replicate a list multiple times, as in
# ```python
# [1, 2, 3, 1, 2, 3, 1, 2, 3]
# ```

# %%
[1, 2, 3] * 10
# Out:
# [1,
#  2,
#  3,
#  1,
#  2,
#  3,
#  1,
#  2,
#  3,
#  1,
#  2,
#  3,
#  1,
#  2,
#  3,
#  1,
#  2,
#  3,
#  1,
#  2,
#  3,
#  1,
#  2,
#  3,
#  1,
#  2,
#  3,
#  1,
#  2,
#  3]

# %% [markdown]
# We'll look at functions that do this later

# %% [markdown]
# ### Modifying multiple items

# %% [markdown]
# How would u modify the below list to get the output as shown below?

# %%
a = [1, 2, 3, 4, 5, 6, 7]

# %%
a [2:5] = [13, 14, 15]

# %%
a
# Out:
# [1, 2, 13, 14, 15, 6, 7]

# %% [markdown]
# The same can be used to delete elements from the list

# %%
a [3:5] = []

# %%
a
# Out:
# [1, 2, 13, 6, 7]

# %% [markdown]
# And to clear the list

# %%
a [:] = []

# %%
a
# Out:
# []

# %% [markdown]
# ### Nested lists

# %%
a = [
    [1, 2, 3],
    [4, 5, 6],
    [7, 8, 9]
]

# %%
a
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %% [markdown]
# Access it using multiple indices

# %%
a [0] [1]
# Out:
# 2

# %% [markdown]
# ### Functions that operate on lists

# %% [markdown]
# #### Append

# %%
a = [1, 2, 3, 4]

# %%
a.append (10)

# %%
a
# Out:
# [1, 2, 3, 4, 10]

# %% [markdown]
# Question: What if you wanna append multiple items to the list? \
# Will the below work?

# %%
a.append ([11, 12, 13])

# %%
a
# Out:
# [1, 2, 3, 4, 10, [11, 12, 13]]

# %% [markdown]
# #### Extend

# %%
a = [1, 2, 3, 4, 10]
a.extend ([11, 12, 13])

# %%
a
# Out:
# [1, 2, 3, 4, 10, 11, 12, 13]

# %% [markdown]
# #### Count

# %%
a = [1, 2, 3, 4, 5, 5, 4, 3, 2, 1, 0]

# %%
a.count (1)
# Out:
# 2

# %% [markdown]
# #### Index

# %%
a = [1, 2, 3, 4]
a.index (3)
# Out:
# 2

# %% [markdown]
# Question: What would be the output of the following?

# %%
a = [1, 2, 3, 4, 5, 5, 4, 3, 2, 1, 0]
a.index (5)
# Out:
# 4

# %% [markdown]
# Ans: Returns the first occurance of the item if found

# %% [markdown]
# Question: What happens if the value is not in the list?

# %%
a = [1, 2, 3, 4]
a.index (10)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/t7/zv08vvlj7zn5b8yc7ywj4tl80000gn/T/ipykernel_1745/2319998427.py in <module>
#       1 a = [1, 2, 3, 4]
# ----> 2 a.index (10)
#
# ValueError: 10 is not in list

# %% [markdown]
# #### Insert

# %%
a = [1, 2, 3, 4]
a.insert (2, 100)

# %%
a
# Out:
# [1, 2, 100, 3, 4]

# %%
a.insert (10, 5)
a
# Out:
# [1, 2, 100, 3, 4, 5]

# %% [markdown]
# #### Pop

# %%
a = [1, 2, 3, 4, 5]
a.pop ()
# Out:
# 5

# %%
a
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# What if u wanna pop out other than the last element?

# %%
a.pop (2)
# Out:
# 3

# %%
a
# Out:
# [1, 2, 4]

# %% [markdown]
# How would you pop out an element with a particular value?

# %%
a = [10, 20, 30, 40, 50, 60]

# %%
a.pop (a.index (30))
# Out:
# 30

# %%
a
# Out:
# [10, 20, 40, 50, 60]

# %% [markdown]
# #### Remove
# The same can be done easily with `remove`

# %%
a = [10, 20, 30, 40, 50]

# %%
a.remove (30)

# %%
a
# Out:
# [10, 20, 40, 50]

# %% [markdown]
# `reverse`, `sort` and `copy` are other functions that can work with list objects\
# **Note:** They operate in place

# %% [markdown]
# ## Tuple

# %% [markdown]
# It one of the sequence type data structures, similar to lists, but they are immutable

# %%
tup = ('a', 'b', 'c')

# %%
tup
# Out:
# ('a', 'b', 'c')

# %% [markdown]
# #### Accessing it

# %%
tup [1]
# Out:
# 'b'

# %% [markdown]
# Will this work?

# %%
tup [0] = 10
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/t7/zv08vvlj7zn5b8yc7ywj4tl80000gn/T/ipykernel_1745/355300594.py in <module>
# ----> 1 tup [0] = 10
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# Can contain heterogenous objects

# %%
tup = (1, 2, 'apple', 'ball')

# %%
tup
# Out:
# (1, 2, 'apple', 'ball')

# %%
tup [1:3]
# Out:
# (2, 'apple')

# %% [markdown]
# How would you create an empty tuple?

# %%
tup = () # or use tuple ()

# %%
tup
# Out:
# ()

# %% [markdown]
# How would you create a tuple with only one entry?

# %%
tup = 'one',  'two'

# %%
tup
# Out:
# ('one', 'two')

# %% [markdown]
# `count` and `index` are the functions that can be used with tuples (similar to the one defined with lists)

# %% [markdown]
# ## Set

# %% [markdown]
# A set is an unordered collection with no duplicate elements.

# %% [markdown]
# #### Starting with an empty set and adding elements to it

# %%
s = set ()

# %%
s.add (10)

# %%
s
# Out:
# {10}

# %% [markdown]
# #### Creating a set using iterables

# %%
s = set ([1, 2, 3, 4, 5, 2, 3, 0])

# %%
s
# Out:
# {0, 1, 2, 3, 4, 5}

# %% [markdown]
# #### Creating using curly braces

# %%
s = {10, 20, 30, 40, 30, 20}

# %%
s
# Out:
# {10, 20, 30, 40}

# %% [markdown]
# Question: What is the output of the following?

# %%
s = {[1, 2, 3], [10, 20, 30]}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/t7/zv08vvlj7zn5b8yc7ywj4tl80000gn/T/ipykernel_1745/3001690875.py in <module>
# ----> 1 s = {[1, 2, 3], [10, 20, 30]}
#
# TypeError: unhashable type: 'list'

# %% [markdown]
# Question: What values can it hold? \
# _Hint:_ Think about the properties of set

# %% [markdown]
# Question: Will this work?

# %%
s [0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/t7/zv08vvlj7zn5b8yc7ywj4tl80000gn/T/ipykernel_1745/367594570.py in <module>
# ----> 1 s [0]
#
# TypeError: 'set' object is not subscriptable

# %% [markdown]
# Question: Can you find the unique elements of this list?
# ```python
# a = [1, 2, 3, 4, 4, 4, 4, 4, 5, 3, 3, 3]
# ```

# %% [markdown]
# #### Uses of sets

# %% [markdown]
# - Eleminating duplicates
# - Testing for membership

# %% [markdown]
# #### Set Operation
# - union
# - intersection
# - difference
# - symmetric difference.

# %%
s1 = {1, 2, 3, 4, 5}
s2 = {4, 5, 6, 7, 8}

# %%
s1.intersection (s2)

# %%
s1.union (s2)

# %%
s1.difference (s2)

# %%
s1.symmetric_difference (s2)

# %% [markdown]
# Question: What would the following command do?
# ```python
# s = {}
# ```
#
# Will it create an empty set?

# %% [markdown]
# Ans: Nope, it could create an empty dictionary

# %% [markdown]
# ## Dictionary

# %% [markdown]
# Unlike sequences, which are indexed by a range of numbers, dictionaries are indexed by keys, which can be any immutable type

# %%
d = {'a':1, 'b':2, 'c':3}

# %%
d

# %% [markdown]
# Which of the following could be used as dictionary keys?
# - Int/Float
# - Strings
# - Lists
# - Tuples
# - Sets
# - Dictionary itself

# %% [markdown]
# How to get only the keys?

# %%
d.keys ()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/t7/zv08vvlj7zn5b8yc7ywj4tl80000gn/T/ipykernel_1745/3920935513.py in <module>
# ----> 1 d.keys ()
#
# NameError: name 'd' is not defined

# %% [markdown]
# What about the values?

# %%
d.values ()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/t7/zv08vvlj7zn5b8yc7ywj4tl80000gn/T/ipykernel_1745/1575476292.py in <module>
# ----> 1 d.values ()
#
# NameError: name 'd' is not defined

# %% [markdown]
# What if both the key:values are required?

# %%
d.items ()

# %%
d.get ('d', 'unknown')

# %%
d.pop ('a')

# %% [markdown]
# Question: What happens if we call pop once more on a?

# %%
d.pop ('a')

# %%
d.pop ('a', 'useful info')

# %% [markdown]
# What if you wanna add a key:value pair to ur dictionary but don't want to override if already exist?

# %% [markdown]
# One possible way is to check for the key using `get` and then act accordingly

# %%
if not d.get ('d'):
    # Add
    d ['d'] = 'blah'

# %%
d

# %%
d.setdefault ('d', '123')

# %%
d.setdefault ('e', '1234')

# %%
d

# %% [markdown]
# Question: What's the output of the following?

# %%
list ({'a':1, 'b':2})

# %% [markdown]
# It iterates over the keys by default. How would you get the values?

# %% [markdown]
# Question: What's the output?

# %%
d

# %%
list (d)

# %% [markdown]
# ## Just for fun

# %% [markdown]
# Lets say we `str` to convert a list to string. How can you convert it back to a list?

# %%
str ([1, 2])

# %%
eval (str ([1, 2]))

# %% [markdown]
# ## Deepcopy

# %%
import copy

# %%
x = [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
y = copy.deepcopy (x)

# %%
y [0] [0] = 100
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/t7/zv08vvlj7zn5b8yc7ywj4tl80000gn/T/ipykernel_1745/1320688752.py in <module>
# ----> 1 y [0] [0] = 100
#
# NameError: name 'y' is not defined

# %%
x, y
