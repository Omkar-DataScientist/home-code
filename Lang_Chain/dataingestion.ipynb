# %%
from langchain_community.document_loaders import PyPDFLoader
from langchain_community.document_loaders import TextLoader

# %%
loader=TextLoader('speech.txt')
loader

# %%
textdocuments=loader.load()
textdocuments

# %%
# Out:
# [Document(metadata={'source': 'speech.txt'}, page_content='"May your accuracy always be high, and your biases low!",\n        "Wishing you a year of optimal parameters and zero overfitting!",\n        "May your life\'s data be perfectly labeled and your features always significant!",\n        "Here\'s to a future with more positive outcomes and fewer false positives!",\n        "May your happiness metrics consistently show an upward trend!",\n        "Wishing you a year of successful model deployments and abundant insights!",\n        "May your journey through life be as smooth as a well-converged gradient descent!",\n        "Happy Birthday! May your joy be deep-learned and your celebrations massively parallel!",\n        "May your special day be filled with precision, recall, and a high F1-score of happiness!",\n        "Wishing you a year where every prediction is true, and every dream is realized!",\n        "May your features be engineering gold, and your insights truly novel!",
# ...

# %%
from langchain_community.document_loaders import PyPDFLoader
loader1=PyPDFLoader('SalarySlip_November.pdf')
loader1
pdfdocuments=loader1.load()

# %%
pdfdocuments
# Out:
# [Document(metadata={'producer': 'Microsoft Reporting Services PDF Rendering Extension 2019.11.0.0', 'creator': 'Microsoft Reporting Services 2019.11.0.0', 'creationdate': '2024-12-03T10:12:13+05:30', 'title': 'Salary', 'author': '', 'subject': '', 'source': 'SalarySlip_November.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1'}, page_content='Location \nDesignation \nBank A/C No. \nNo. of days paid for \nNovember 2024\nS06A/0247/60301211-Santander\nDATA ARCHITECT\n50100425632747  HDFC BANK\n30.00\nP.F. No\nE.P.S. No.\nPAN     \nUAN\nESI No.\nBasic\nDOJ\nDLNHP/0033691/00E/CEPF/0055312\nDS/NHP/0033691/00E/0057512\nBBNPC9601A\n101080806280\n089584\n20-June-2024\nEarnings\nStatutory Deductions\nScheme Deductions\n*For the Month of November 2024\nBASIC\n89584.00\nPF\n10750.00\nHRA\n44792.00\nTax-FTM\n61492.00\nCON ALL\n42589.00\nPROFTAX\n200.00\nFlexi\n120207.00\nOdDyAl\n4000.00\nEarnings\n       \n301172.00\nDeductions\n72442.00\nNet Pay\n228730.00\nPayslip for the month \n:  \n   \nN
# ...

# %%
## Web based loader
from langchain_community.document_loaders import WebBaseLoader
import bs4
loader=WebBaseLoader(web_paths=("https://mail.google.com/mail/u/0/?tab=rm&ogbl#chat/home",),
                     bs_kwargs=dict(parse_only=bs4.SoupStrainer(
                         class_=("post-title","post-content","post-header")
                     ))
                     )

# %%
loader.load()
# Out:
# [Document(metadata={'source': 'https://mail.google.com/mail/u/0/?tab=rm&ogbl#chat/home'}, page_content='')]

# %%
# !oolama serve
# Out:
# zsh:1: command not found: oolama

# %%
# !ollama pull llama3.1:8b
# Out:
# pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠋ pulling manifest ⠙ pulling manifest
# pulling 667b0c1932bc: 100% ▕██████████████████▏ 4.9 GB
# pulling 948af2743fc7: 100% ▕██████████████████▏ 1.5 KB
# pulling 0ba8f0e314b4: 100% ▕██████████████████▏  12 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 455f34728c9b: 100% ▕██████████████████▏  487 B
# verifying sha256 digest
# writing manifest
# success

# %%
# !ollama list
# Out:
# NAME           ID              SIZE      MODIFIED
# llama3.1:8b    46e0c10c039e    4.9 GB    54 seconds ago

# %%
# !ollama serve
# Out:
# Error: listen tcp 127.0.0.1:11434: bind: address already in use

# %%
pip install langchain-ollama
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [langchain-ollama]
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_ollama import OllamaLLM

llm = OllamaLLM(model="llama3.1:8b")
response = llm.invoke("The first man on the moon was ...")
print(response)
# Out:
# ...Neil Armstrong. He became the first person to set foot on the Moon on July 20, 1969, during the Apollo 11 mission. When he stepped out of the lunar module Eagle and onto the Moon's surface, he famously declared: "That's one small step for man, one giant leap for mankind."

# %%
from langchain_ollama import ChatOllama

chat_model = ChatOllama(model="llama3.1:8b")
ai_message = chat_model.invoke("Who was the first man on the moon?")
print(ai_message.content)
# Out:
# The first men to walk on the Moon were actually two astronauts, not just one. On July 20, 1969, NASA's Apollo 11 mission made history by landing on the lunar surface.
#
# The two astronauts who set foot on the Moon were:
#
# 1. **Neil Armstrong**: He stepped out of the lunar module Eagle and onto the Moon's surface at 2:56 UTC on July 21, 1969 (July 20 in Houston time). As he took his first steps, he famously declared, "That's one small step for man, one giant leap for mankind."
# 2. **Edwin "Buzz" Aldrin**: He joined Armstrong on the surface shortly afterwards and together they spent about two and a half hours exploring the Moon.
#
# Michael Collins remained in orbit around the Moon in the command module Columbia, playing a crucial role in supporting his fellow astronauts during the mission.
#
# So while Neil Armstrong was the first person to set foot on the Moon, it's more accurate to say that he and Buzz Aldrin were the first two humans to walk on the lunar surface.
